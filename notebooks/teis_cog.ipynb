# %% [markdown]
# based on mob code done with Daniel

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
teis_df=pd.read_excel('../data/bdi3_all_evals.xlsx')

# %%
teis_df=teis_df.drop_duplicates()
teis_df.reset_index()
teis_df= teis_df.rename(columns={'Location - Sub Level 1':'Location'})

# %%
cog_sub_df=teis_df[['Child ID','Gender', 'Cognitive-Attention and Memory SS','Cognitive-Reasoning / Academic Skills SS','Cognitive-Perception and Concepts SS']]
cog_sub_df
# Out:
#       Child ID Gender  Cognitive-Attention and Memory SS  \
# 0        44879      F                                7.0
# 1        47795      F                                9.0
# 2        54340      M                                8.0
# 3        54344      F                               14.0
# 4        54515      M                                9.0
# ...        ...    ...                                ...
# 23942  SP03287      F                                9.0
# 23943  SP03288      F                               13.0
# 23944  SP03289      F                               10.0
# 23945  SP03290      M                                7.0
# 23946  SP03291      M                                7.0
#
#        Cognitive-Reasoning / Academic Skills SS  \
# 0                                           NaN
# 1                                          14.0
# 2                                           NaN
# 3                                           NaN
# ...

# %%
cog_am_avg = cog_sub_df.groupby('Gender')['Cognitive-Attention and Memory SS'].agg(np.mean).to_frame()
cog_am_avg
# Out:
#         Cognitive-Attention and Memory SS
# Gender
# F                                8.585497
# M                                8.278410
# U                                9.251701

# %%
cog_ra_avg = cog_sub_df.groupby('Gender')['Cognitive-Reasoning / Academic Skills SS'].agg(np.mean).to_frame()
cog_ra_avg
# Out:
#         Cognitive-Reasoning / Academic Skills SS
# Gender
# F                                       8.397452
# M                                       7.921494
# U                                       9.050955

# %%
cog_pc_avg = cog_sub_df.groupby('Gender')['Cognitive-Perception and Concepts SS'].agg(np.mean).to_frame()
cog_pc_avg
# Out:
#         Cognitive-Perception and Concepts SS
# Gender
# F                                   8.116298
# M                                   7.560345
# U                                   8.785714

# %%
cog_sub_avg= cog_am_avg.merge(cog_ra_avg, how='outer', on='Gender')
cog_sub_avg
# Out:
#         Cognitive-Attention and Memory SS  \
# Gender
# F                                8.585497
# M                                8.278410
# U                                9.251701
#
#         Cognitive-Reasoning / Academic Skills SS
# Gender
# F                                       8.397452
# M                                       7.921494
# U                                       9.050955

# %%
cog_sub_avg= cog_sub_avg.merge(cog_pc_avg, how='outer', on='Gender')
cog_sub_avg
# Out:
#         Cognitive-Attention and Memory SS  \
# Gender
# F                                8.585497
# M                                8.278410
# U                                9.251701
#
#         Cognitive-Reasoning / Academic Skills SS  \
# Gender
# F                                       8.397452
# M                                       7.921494
# U                                       9.050955
#
#         Cognitive-Perception and Concepts SS
# Gender
# F                                   8.116298
# M                                   7.560345
# U                                   8.785714
