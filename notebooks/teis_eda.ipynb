# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
teis_df = pd.read_excel(r'/Users/tkwhi/Documents/nss_data_analytics/Projects/python/teis-concatahoula_leopards/data/bdi3_all_evals.xlsx')

# %%
teis_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23947 entries, 0 to 23946
# Columns: 209 entries, Child ID to Cognitive-Perception and Concepts NCE
# dtypes: datetime64[ns](14), float64(69), object(126)
# memory usage: 38.2+ MB

# %%
teis_df.info
# Out:
# <bound method DataFrame.info of       Child ID Gender Date of Birth Location - Sub Level 1  \
# 0        44879      F    2022-09-27              Southwest
# 1        47795      F    2020-12-23      Greater Nashville
# 2        54340      M    2021-06-22        First Tennessee
# 3        54344      F    2022-03-07    Southeast Tennessee
# 4        54515      M    2021-11-04          Memphis Delta
# ...        ...    ...           ...                    ...
# 23942  SP03287      F    2023-09-25          Memphis Delta
# 23943  SP03288      F    2021-05-18          South Central
# 23944  SP03289      F    2021-10-31          South Central
# 23945  SP03290      M    2020-03-25          Memphis Delta
# 23946  SP03291      M    2023-09-18      Greater Nashville
#
#                       Program Label  Adaptive Sum of Scaled Scores  \
# 0      BDI-3 Eligibility Evaluation                            7.0
# 1      BDI-3 Eligibility Evaluation                           16.0
# ...

# %%
teis_df.head()
# Out:
#   Child ID Gender Date of Birth Location - Sub Level 1  \
# 0    44879      F    2022-09-27              Southwest
# 1    47795      F    2020-12-23      Greater Nashville
# 2    54340      M    2021-06-22        First Tennessee
# 3    54344      F    2022-03-07    Southeast Tennessee
# 4    54515      M    2021-11-04          Memphis Delta
#
#                   Program Label  Adaptive Sum of Scaled Scores  \
# 0  BDI-3 Eligibility Evaluation                            7.0
# 1  BDI-3 Eligibility Evaluation                           16.0
# 2  BDI-3 Eligibility Evaluation                            8.0
# 3  BDI-3 Eligibility Evaluation                           13.0
# 4  BDI-3 Eligibility Evaluation                            5.0
#
#    Adaptive Developmental Quotient Adaptive Percentile Rank  \
# 0                             85.0                       16
# 1                             88.0                       21
# 2                             90.0                       25
# ...

# %%
#dropping duplicate rows

teis_df_no_dupes = teis_df.drop_duplicates()

# %%
teis_df_no_dupes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19500 entries, 0 to 23946
# Columns: 209 entries, Child ID to Cognitive-Perception and Concepts NCE
# dtypes: datetime64[ns](14), float64(69), object(126)
# memory usage: 31.2+ MB

# %%
# checking on a known duplicate

teis_df_no_dupes.loc[teis_df_no_dupes['Child ID']==404042 ]
# Out:
#    Child ID Gender Date of Birth Location - Sub Level 1  \
# 19   404042      M    2020-03-17       Upper Cumberland
#
#               Program Label  Adaptive Sum of Scaled Scores  \
# 19  BDI-3 Annual Evaluation                            2.0
#
#     Adaptive Developmental Quotient Adaptive Percentile Rank  \
# 19                             46.0                     <0.1
#
#    Adaptive 95% Confidence Interval Adaptive RDI  ...  \
# 19                            42-56        <1/90  ...
#
#    Cognitive-Perception and Concepts RS  Cognitive-Perception and Concepts SS  \
# 19                                  4.0                                   1.0
#
#    Cognitive-Perception and Concepts PR  Cognitive-Perception and Concepts AE  \
# 19                                   <1                                     2
#
#     Cognitive-Perception and Concepts RDI  \
# 19                                  <1/90
#
#    Cognitive-Perception and Concepts CSS  \
# ...

# %%
teis_df_no_dupes.describe()
# Out:
#        Adaptive Sum of Scaled Scores  Adaptive Developmental Quotient  \
# count                   19493.000000                     19493.000000
# mean                       11.412712                        87.435079
# std                         5.822943                        17.438731
# min                         1.000000                        46.000000
# 25%                         7.000000                        76.000000
# 50%                        11.000000                        88.000000
# 75%                        15.000000                       100.000000
# max                        36.000000                       148.000000
#
#        Adaptive T-Score  Social-Emotional Sum of Scaled Scores  \
# count      19493.000000                           19483.000000
# mean          41.624583                              22.381153
# std           11.612715                               7.519204
# min           14.000000                               2.000000
# ...

# %%
type(teis_df_no_dupes['Adaptive RDI'][2])
# Out:
# str

# %%
#trying to clean up timestamps in Adaptive RDI column

#beginning with isolating the column so it's easier to manipulate

ad_rdi_df = teis_df_no_dupes['Adaptive RDI']

# %%
ad_rdi_df.head()
# Out:
# 0                  39/90
# 1                  79/90
# 2                  77/90
# 3                  99/90
# 4    1990-09-01 00:00:00
# Name: Adaptive RDI, dtype: object

# %%
ad_rdi_df.reset_index()
# Out:
#        index         Adaptive RDI
# 0          0                39/90
# 1          1                79/90
# 2          2                77/90
# 3          3                99/90
# 4          4  1990-09-01 00:00:00
# ...      ...                  ...
# 19495  23942                99/90
# 19496  23943                96/90
# 19497  23944                92/90
# 19498  23945                66/90
# 19499  23946                94/90
#
# [19500 rows x 2 columns]

# %%
# think I need to use regex and apply it to each row
# how?

re.findall(f'1990.+1.+', '1990-09-01 00:00:00')
re.sub('1990.+1.+', '9/90', '1990-09-01 00:00:00')
# Out:
# '9/90'

# %%
ad_rdi_df.head()
# Out:
# 0                  39/90
# 1                  79/90
# 2                  77/90
# 3                  99/90
# 4    1990-09-01 00:00:00
# Name: Adaptive RDI, dtype: object

# %%
def date_fix(date):
    return re.sub('1990.+1.+', '9/90', date)

date_fix('1990-09-01 00:00:00')
# Out:
# '9/90'

# %%
ad_rdi_no_date = date_fix(ad_rdi_df['Adaptive RDI'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\tkwhi\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\tkwhi\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Adaptive RDI'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20404/3697259712.py in <module>
# ...

# %%
ad_rdi_df['Adaptive RDI'] = ad_rdi_df['Adaptive RDI'].to_string()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\tkwhi\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\tkwhi\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Adaptive RDI'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20404/2998146619.py in <module>
# ...

# %%
for x in ad_rdi_df['Adaptive RDI']:
    if x == '1990-09-01 00:00:00':
        re.sub('1990.+1.+', '9/90', '1990-09-01 00:00:00')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\tkwhi\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\tkwhi\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Adaptive RDI'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20404/146671561.py in <module>
# ----> 1 for x in ad_rdi_df['Adaptive RDI']:
# ...
